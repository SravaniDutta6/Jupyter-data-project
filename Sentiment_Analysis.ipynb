# %%
#Import the Data Set and do the data preprocessing
#Problem Statement -
# Develop a sentiment analysis model to classify reiviews as positive or negative.

#Preprocess the review text using techniques such as Lower casing, removing stop words and Lematizatio

#use the trained model accurately predict the sentiment of new, unseen reviews.

# %%
import pandas as pd

# %%
data = pd.read_csv('Reviews.csv')

# %%
print(data)
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %%
#Review the top 5 rows
data.head() # here giving arguments is optional, by default it will take 5 - which gives first 5 records
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
#Review the ladt 5 rows
data.tail()
# Out:
#                                                 Review  Liked
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0

# %%
data.tail(6)
# Out:
#                                                 Review  Liked
# 994           I can't tell you how disappointed I was.      0
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  1000 non-null   object
#  1   Liked   1000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB

# %%
#TO CHECK NULL VALUES
data.isnull().sum()
# Out:
# Review    0
# Liked     0
# dtype: int64

# %%
#TO CHECK THE DUPLICATE VALUES
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
# TO UNDERSTAND THE DATA IN GRAPHICAL/PICTORIAL MANNER, 
#we need to use EDA - Exploratory Data Analysis

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\dutta\.ipython\python\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dutta\.ipython\python\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\dutta\.ipython\python\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dutta\.ipython\python\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dutta\.ipython\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dutta\.ipython\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dutta\.ipython\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dutta\.ipython\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dutta\.ipython\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dutta\.ipython\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dutta\.ipython\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dutta\.ipython\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dutta\.ipython\python\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dutta\.ipython\python\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dutta\.ipython\python\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud

# %%
combined_text = "".join(data['Review']) # combine all review text into one string

# %%
wordcloud = WordCloud(width=800, height = 400, background_color = 'white').generate(combined_text)

# %%
#plot the word cloud
plt.figure(figsize=(10,6))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('Word Cloud of Reviews')
plt.show()
#The bigger the font of the word, that many times that word is repeated in the dataset.

# %%
from collections import Counter

# %%
targeted_words = ['good', 'great', 'amazing', 'love', 'worth', 'food', 'good', 'place']
all_words = " ".join(data['Review']).lower().split() # flattern reviews into a singlie list of words
word_counts = Counter(all_words) # count of target words
target_word_count = {word: word_counts[word] for word in targeted_words}

# %%
#plotting
plt.figure(figsize=(8,6))
plt.bar(target_word_count.keys(), target_word_count.values(), color = ['blue', 'green', 'orange', 'red', 'blue'])
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Frequency of specific words in reviews')
plt.show()

# %%
# Text preprocessing

# %%
# Converting a dataset into lower case
lowercased_text = data['Review'].str.lower()
print(lowercased_text)
# Out:
# 0                               wow... loved this place.
# 1                                     crust is not good.
# 2              not tasty and the texture was just nasty.
# 3      stopped by during the late may bank holiday of...
# 4      the selection on the menu was great and so wer...
#                              ...
# 995    i think food should have flavor and texture an...
# 996                             appetite instantly gone.
# 997    overall i was not impressed and would not go b...
# 998    the whole experience was underwhelming, and i ...
# 999    then, as if i hadn't wasted enough of my life ...
# Name: Review, Length: 1000, dtype: object

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\dutta\.ipython\python\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\dutta\.ipython\python\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\dutta\.ipython\python\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dutta\.ipython\python\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\dutta\.ipython\python\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\dutta\.ipython\python\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Tokenization
from nltk.tokenize import word_tokenize
#import nltk
#nltk.download('punkt')

#import nltk
#nltk.download('stopwords')

# %%
data['Tokens'] = data['Review'].apply(word_tokenize)
print(data['Tokens'])
# Out:
# 0                      [Wow, ..., Loved, this, place, .]
# 1                              [Crust, is, not, good, .]
# 2      [Not, tasty, and, the, texture, was, just, nas...
# 3      [Stopped, by, during, the, late, May, bank, ho...
# 4      [The, selection, on, the, menu, was, great, an...
#                              ...
# 995    [I, think, food, should, have, flavor, and, te...
# 996                       [Appetite, instantly, gone, .]
# 997    [Overall, I, was, not, impressed, and, would, ...
# 998    [The, whole, experience, was, underwhelming, ,...
# 999    [Then, ,, as, if, I, had, n't, wasted, enough,...
# Name: Tokens, Length: 1000, dtype: object

# %%
#Removing Stop Words
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stop_words = set(stopwords.words('english'))

# %%
data['Tokens'] = data['Review'].apply(lambda x: [word for word in word_tokenize(x) if word not in stop_words])

# %%
print(data['Tokens'])
# Out:
# 0                            [Wow, ..., Loved, place, .]
# 1                                       [Crust, good, .]
# 2                        [Not, tasty, texture, nasty, .]
# 3      [Stopped, late, May, bank, holiday, Rick, Stev...
# 4               [The, selection, menu, great, prices, .]
#                              ...
# 995        [I, think, food, flavor, texture, lacking, .]
# 996                       [Appetite, instantly, gone, .]
# 997          [Overall, I, impressed, would, go, back, .]
# 998    [The, whole, experience, underwhelming, ,, I, ...
# 999    [Then, ,, I, n't, wasted, enough, life, ,, pou...
# Name: Tokens, Length: 1000, dtype: object

# %%
#stemming
from nltk.stem import PorterStemmer

# %%
stemmer = PorterStemmer()

# %%
data['stemmed'] = data['Review'].apply(lambda x: " ".join([stemmer.stem(word) for word in word_tokenize(x)]))

# %%
print(data['stemmed'])
# Out:
# 0                               wow ... love thi place .
# 1                                    crust is not good .
# 2               not tasti and the textur wa just nasti .
# 3      stop by dure the late may bank holiday off ric...
# 4      the select on the menu wa great and so were th...
#                              ...
# 995    i think food should have flavor and textur and...
# 996                             appetit instantli gone .
# 997      overal i wa not impress and would not go back .
# 998    the whole experi wa underwhelm , and i think w...
# 999    then , as if i had n't wast enough of my life ...
# Name: stemmed, Length: 1000, dtype: object

# %%
data['stemmed'].value_counts()
# Out:
# stemmed
# # name ?                                                                                                                               4
# the food wa terribl .                                                                                                                  2
# i would not recommend thi place .                                                                                                      2
# i love thi place .                                                                                                                     2
# i wo n't be back .                                                                                                                     2
#                                                                                                                                       ..
# omg , the food wa delicioso !                                                                                                          1
# there is noth authent about thi place .                                                                                                1
# the spaghetti is noth special whatsoev .                                                                                               1
# of all the dish , the salmon wa the best , but all were great .                                                                        1
# then , as if i had n't wast enough of my life there , they pour salt in the wound by draw out the time it took to bring the check .    1
# Name: count, Length: 993, dtype: int64

# %%
# Lemmatization - Removal of suffix from base words, ex: running --> run
# Lemmatization is the process transforming a word into its base or dictionary form
#example is better is Lemmtized to good
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dutta\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# %%
lemmatizer = WordNetLemmatizer()

# %%
data['Lemmatized'] = data['Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word, pos=wordnet.VERB) for word in word_tokenize(x)]))

# %%
# Remove the numbers
import re
data['No_Numbers'] = data['Review'].apply(lambda x: re.sub(r'\d+', ' ', x))

# %%
print(data['No_Numbers'])
# Out:
# 0                               Wow... Loved this place.
# 1                                     Crust is not good.
# 2              Not tasty and the texture was just nasty.
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone.
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming, and I ...
# 999    Then, as if I hadn't wasted enough of my life ...
# Name: No_Numbers, Length: 1000, dtype: object

# %%
data['cleaned_txt'] = data['Review'].apply(lambda x: re.sub(r'[^A-Za-z0-9\s]', ' ', x))

# %%
print(data['cleaned_txt'])
# Out:
# 0                               Wow    Loved this place
# 1                                     Crust is not good
# 2              Not tasty and the texture was just nasty
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming  and I ...
# 999    Then  as if I hadn t wasted enough of my life ...
# Name: cleaned_txt, Length: 1000, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Review       1000 non-null   object
#  1   Liked        1000 non-null   int64
#  2   Tokens       1000 non-null   object
#  3   stemmed      1000 non-null   object
#  4   Lemmatized   1000 non-null   object
#  5   No_Numbers   1000 non-null   object
#  6   cleaned_txt  1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %%
pip install contractions
# Out:
# Requirement already satisfied: contractions in c:\users\dutta\.ipython\python\lib\site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in c:\users\dutta\.ipython\python\lib\site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in c:\users\dutta\.ipython\python\lib\site-packages (from textsearch>=0.0.21->contractions) (0.3.3)
# Requirement already satisfied: pyahocorasick in c:\users\dutta\.ipython\python\lib\site-packages (from textsearch>=0.0.21->contractions) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Normalization

import contractions
data['Expanded'] = data['Review'].apply(contractions.fix)

# %%
print(data['Expanded'])
# Out:
# 0                               Wow... Loved this place.
# 1                                     Crust is not good.
# 2              Not tasty and the texture was just nasty.
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone.
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming, and I ...
# 999    Then, as if I had not wasted enough of my life...
# Name: Expanded, Length: 1000, dtype: object

# %%
pip install emoji
# Out:
# Requirement already satisfied: emoji in c:\users\dutta\.ipython\python\lib\site-packages (2.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import emoji
data['Emoji'] = data['Review'].apply(emoji.demojize)

# %%
# Removing HTML tags
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\dutta\.ipython\python\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dutta\.ipython\python\lib\site-packages (from beautifulsoup4) (2.5)

# %%
from bs4 import BeautifulSoup

# %%
data['cleaned'] = data['Review'].apply(lambda x: BeautifulSoup(x, "html.parser").get_text())
# Out:
# C:\Users\dutta\AppData\Local\Temp\ipykernel_23740\748593722.py:1: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   data['cleaned'] = data['Review'].apply(lambda x: BeautifulSoup(x, "html.parser").get_text())

# %%
print(data['cleaned'])
# Out:
# 0                               Wow... Loved this place.
# 1                                     Crust is not good.
# 2              Not tasty and the texture was just nasty.
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone.
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming, and I ...
# 999    Then, as if I hadn't wasted enough of my life ...
# Name: cleaned, Length: 1000, dtype: object
